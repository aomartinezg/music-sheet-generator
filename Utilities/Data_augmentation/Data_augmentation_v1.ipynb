# %%
import librosa
import soundfile as sf
import IPython.display as ipd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## 1) Adding white noise

# %% [markdown]
# This first deformation consists of adding a white noise to the original sound. The onsets retrieved for the original mp3 file should then remain the same.

# %%
# %run ../Utilities.ipynb
# Out:
# Using TensorFlow backend.

# %%
filename = "Guitar_noamp_riff2_11.mp3"

# %%
z = load_file("../../Samples/Guitar/Riffs/" + filename, 8000)

# %%
ipd.Audio(z, rate=8000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
def f(x):
    plt.figure(figsize=(18,6))
    plt.plot(x)

# %%
f(z)

# %%
a = z + np.random.random(size=32449) * 0.1
f(a)

# %%
ipd.Audio(a, rate=8000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# !pwd
# Out:
# /home/ainhoa/music_sheet/music-sheet-generator_v2/Utilities/Data_augmentation

# %%
# !cd ../../../Samples/Guitar/Synthetic_riffs
# Out:
# /usr/bin/sh: line 0: cd: ../../../Samples/Guitar/Synthetic_riffs: No such file or directory

# %%
sf.write("../../Samples/Guitar/Synthetic_riffs/" + "Whitenoise_" + filename + ".wav", a, 8000)
