# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import IPython.display as ipd

# %%
# %run ../../Utilities.ipynb

# %%
notes0 = waveform("../../../Samples/Guitar/Ind_notes/Guitar_noamp_string1_0.mp3")

# %%
notes1 = waveform("../../../Samples/Guitar/Ind_notes/Guitar_noamp_string2_0.mp3")

# %%
ipd.Audio(notes0.y, rate=8000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
ipd.Audio(notes1.y, rate=8000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
chords = notes0.y + notes1.y

# %%
ipd.Audio(chords, rate=8000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
plt.plot(chords)
